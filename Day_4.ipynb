# %% [markdown]
# <a href="https://colab.research.google.com/github/Gautam0804/AI-ML-Learning/blob/main/Day_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Decision Making**

# %% [markdown]
# #if condition

# %%
Syntax:

if condition:
  {
      statements...;
  }

# %%
#Q1 Given the age of person, check if they are eligible to vote. if age is atleast 20, then they are eligible

# %%
age = 19

if age>=20:
  print("Eligible to vote")

# %%
age = 22

if age>=20:
  print("Eligible to vote")
# Out:
# Eligible to vote

# %%
age = 22

if age>=20:
  print("Eligible to vote")
# Out:
# Eligible to vote

# %%
#Q2 Take the password from the user. if it matches "Hello@123" then print wellcome

password = str(input("Enter the password"))
if password == "hello@123":
  print("Wellcome")
# Out:
# Enter the passwordhello@123
# Wellcome

# %% [markdown]
# #if-else condition

# %%
age = 18

if age>=20:
  print("Eligible to vote")
else:
    print("Not Eligible")
# Out:
# Not Eligible

# %%
#Q3 Take the password from the user. if it matches "Hello@123" then print wellcome. Else, print "Invalid Password"
password = input()
if password == "hello@123":
  print("Wllcome")
else:
  print("Invalid password")
# Out:
# hello@123
# Wllcome

# %%
password = input()
if password == "hello@123":
  print("Wllcome")
else:
  print("Invalid password")
# Out:
# gautam@123
# Invalid password

# %%
if 2>3:
  print("A")
else:
  print("B")
print("C")
# Out:
# B
# C

# %%
if 2<3:
  print("A")
else:
  print("B")
print("C")
# Out:
# A
# C

# %% [markdown]
# #elif

# %%
marks = 20
if marks < 30:
  print("Low")
else:
   if (marks >= 31) and (marks <= 70):
    print("Avg")
   else:
    print("High")
# Out:
# Low

# %%
marks = 40
if marks < 30:
  print("Low")
else:
   if (marks >= 31) and (marks <= 70):
    print("Avg")
   else:
    print("High")
# Out:
# Avg

# %%
marks = 85
if marks < 30:
  print("Low")
else:
   if (marks >= 31) and (marks <= 70):
    print("Avg")
   else:
    print("High")
# Out:
# High

# %%
# else if ==> elif

if(2<3):
  print("A")
else:
  print("B")
# Out:
# A

# %%
if(2<3):
  print("A")
elif 5>3:
  print("B")
else:
  print("C")
# Out:
# A

# %%
if(2>3):
  print("A")
elif 5>3:
  print("B")
else:
  print("C")
# Out:
# B

# %%
if(2>3):
  print("A")
elif 5<3:
  print("B")
else:
  print("C")
# Out:
# C

# %%
marks = 20
if marks < 30:
  print("Low")
elif(marks >= 30) and (marks <= 70):
  print("Avg")
else:
  print("High")
# Out:
# Low

# %%
marks = 40
if marks < 30:
  print("Low")
elif(marks >= 30) and (marks <= 70):
  print("Avg")
else:
  print("High")
# Out:
# Avg

# %%
marks = 80
if marks < 30:
  print("Low")
elif(marks >= 30) and (marks <= 70):
  print("Avg")
else:
  print("High")
# Out:
# High

# %%
marks = 30
if marks < 30:
  print("Low")
elif(marks >= 30) and (marks <= 70):
  print("Avg")
else:
  print("High")
# Out:
# Avg

# %%
#coolest code

marks = 30
if marks < 30:
  print("Low")
elif(marks <= 70):
  print("Avg")
else:
  print("High")
# Out:
# Avg
