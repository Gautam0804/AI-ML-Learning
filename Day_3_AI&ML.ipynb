# %% [markdown]
# <a href="https://colab.research.google.com/github/Gautam0804/AI-ML-Learning/blob/main/Day_3_AI%26ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Operators

# %% [markdown]
# #Arithmatic Operatore

# %%
print(9+7)
# Out:
# 16

# %%
print(9-3)
# Out:
# 6

# %%
print(34*4)
# Out:
# 136

# %%
print(30/5)
# Out:
# 6.0

# %%
#Floored division operator
print(20//6)
# Out:
# 3

# %%
print(10//5)
# Out:
# 2

# %%
print(10/5)
# Out:
# 2.0

# %%
#Modulis --> gives remainder --%

print(10%3)
# Out:
# 1

# %%
print(10%6)
# Out:
# 4

# %%
print(10%2)
# Out:
# 0

# %%
# power --> **
print(2**3)
# Out:
# 8

# %%
print(3**2)
# Out:
# 9

# %%
## Creating a calculator
##taking two int as input from the user, and print all

# %%
a = int(input("Enter First Number"))
b = int(input("Enter Second number"))

print("Addition:", a+b)
print("Subtraction:", a-b)
print("Multiplication:", a*b)
print("Division:", a/b)
print("Floored Division:", a//b)
print("Modulus:", a%b)
print("Power:", a**b)
# Out:
# Enter First Number10
# Enter Second number20
# Addition: 30
# Subtraction: -10
# Multiplication: 200
# Division: 0.5
# Floored Division: 0
# Modulus: 10
# Power: 100000000000000000000

# %% [markdown]
# Assignment Operator

# %%
x = 10
print(x)
# Out:
# 10

# %%
x = 10
x += 2 # = x+2
print(x)
# Out:
# 12

# %%
x = 20
x -= 4
print(x)
# Out:
# 16

# %%
x = 30
x *= 4
print(x)
# Out:
# 120

# %%
x = 40
x /= 4
print(x)
# Out:
# 10.0

# %%
x = 40
x //= 4
print(x)
# Out:
# 10

# %%
x = 10
x **= 4
print(x)
# Out:
# 10000

# %% [markdown]
# Comparison Operaor

# %%
10>5
# Out:
# True

# %%
5>9
# Out:
# False

# %%
10>=7
# Out:
# True

# %%
5 <= 3
# Out:
# False

# %%
6<=6
# Out:
# True

# %%
7<7
# Out:
# False

# %%
5==5
# Out:
# True

# %%
5 == 8
# Out:
# False

# %%
6 != 5
# Out:
# True

# %%
7 != 7
# Out:
# False

# %% [markdown]
# Logical Operator

# %%
4>3
# Out:
# True

# %%
5>3
# Out:
# True

# %%
(4>3) and (5>3)
# Out:
# True

# %%
(4>3) and (5<3)
# Out:
# False

# %%
(4<3) and (5<3)
# Out:
# False

# %%
(4>3) or (5>3)
# Out:
# True

# %%
(4>3) or (5<3)
# Out:
# True

# %%
(4<3) or (5<2)
# Out:
# False

# %%
# not --> toggle
#True --> False
#False --> True

(4>7)
# Out:
# False

# %%
not(4>7)
# Out:
# True

# %%
not(4==7)
# Out:
# True

# %%
not(4 != 8)
# Out:
# False

# %%
not((3>3) and (6<3))
# Out:
# True

# %%
not((3>3) or (6<3))
# Out:
# True

# %%
not((3>=3) or (6<3))
# Out:
# False

# %% [markdown]
# MemberShip Operator

# %%
"a" in "Gautam"
# Out:
# True

# %%
"b" in "Gautam"
# Out:
# False

# %%
"c" not in "Gautam"
# Out:
# True
